# %% [markdown]
# # Data Inspection and Cleaning

# %% [markdown]
# #### Importing pandas and reading the dataset

# %%
import pandas as pd
df = pd.read_csv("E:\Waddah\Alex\VS\Metho\DS Methodology Final Project\Dataset\laptops_Dataset.csv")
df.head()
# Out:
#   Brand:                                  Product name  \
# 0    MSI  Titan 18 HX Dragon Edition Norse Myth A2XWJG
# 1    MSI                           Katana 15 HX 14XWGK
# 2   Acer                       NITRO V15-ANV15-51-51H9
# 3   Dell                   Alienware 16 Aurora AC16250
# 4   Dell                   Alienware 16 Aurora AC16250
#
#                   Processor                  Video graphics  \
# 0  Intel Core Ultra 9 285HX    Nvidia GeForce RTX 5090 24GB
# 1     Intel Core i9-14900HX     Nvidia GeForce RTX 5070 8GB
# 2      Intel Core I5-13420H     Nvidia GeForce RTX 4050 6GB
# 3         Intel Core 7 240H  NVIDIA(R) GeForce RTX(TM) 5050
# 4         Intel Core 9 270H     Nvidia GeForce RTX 5060 8GB
#
#   Video graphics Memorey                                                RAM  \
# 0             24GB GDDR7                           96GB DDR5 6400MHz 48GB*2
# 1              8GB GDDR7                                    16GB DDR5 8GB*2
# ...

# %% [markdown]
# #### Understanding the Data

# %%
df.shape
# Out:
# (1033, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand:                  977 non-null    object
#  1   Product name            1033 non-null   object
#  2   Processor               1033 non-null   object
#  3   Video graphics          1032 non-null   object
#  4   Video graphics Memorey  680 non-null    object
#  5   RAM                     1033 non-null   object
#  6   Hard drive              1033 non-null   object
#  7   Display                 1029 non-null   object
#  8   Display Resolution      1013 non-null   object
#  9   Display Refresh Rate    680 non-null    object
#  10  Operating System        1026 non-null   object
#  11  Keyboard                932 non-null    object
#  12  Battery                 1003 non-null   object
#  13  Webcam                  892 non-null    object
# ...

# %%
df.dtypes
# Out:
# Brand:                    object
# Product name              object
# Processor                 object
# Video graphics            object
# Video graphics Memorey    object
# RAM                       object
# Hard drive                object
# Display                   object
# Display Resolution        object
# Display Refresh Rate      object
# Operating System          object
# Keyboard                  object
# Battery                   object
# Webcam                    object
# Connections               object
# Dimensions                object
# Weight                    object
# Colors                    object
# Warranty                  object
# Price                      int64
# Processor Generation      object
# Processor Details         object
# Product number            object
# Power supply type         object
# Laptop Color              object
# Finger Print              object
# SUPPORT SSD M2            object
# Pointing device           object
# ...

# %% [markdown]
# #### Most effecting columns in price

# %%
VIC = df[['Processor','RAM','Hard drive','Display','Video graphics','Display Resolution', 'Display Refresh Rate','Weight', 'Price']]

# %%
VIC.isnull().sum()
# Out:
# Processor                 0
# RAM                       0
# Hard drive                0
# Display                   4
# Video graphics            1
# Display Resolution       20
# Display Refresh Rate    353
# Weight                   40
# Price                     0
# dtype: int64

# %% [markdown]
# #### Filling Missing Values

# %%
df['Display'].describe()
# Out:
# count                                                  1029
# unique                                                  639
# top       15.6" FHD IPS 300nits Anti-glare, 100% sRGB, 1...
# freq                                                     29
# Name: Display, dtype: object

# %%
df['Display Resolution'].describe()
# Out:
# count            1013
# unique             42
# top       1920 x 1080
# freq              436
# Name: Display Resolution, dtype: object

# %%
df['Display Refresh Rate'].describe()
# Out:
# count        680
# unique        10
# top       144 Hz
# freq         258
# Name: Display Refresh Rate, dtype: object

# %%
df['Weight'].describe()
# Out:
# count         993
# unique        205
# top       2.29 kg
# freq           52
# Name: Weight, dtype: object

# %% [markdown]
# ## Two ways to fill missing values
# #### 1. Mode as Mode

# %%
VIC['Display'].fillna('15.6', inplace=True)
VIC['Display Resolution'].fillna(VIC['Display Resolution'].mode()[0], inplace=True)
VIC['Display Refresh Rate'].fillna(VIC['Display Refresh Rate'].mode()[0], inplace=True)
VIC['Weight'].fillna(VIC['Weight'].mode()[0], inplace=True)
VIC['Video graphics'].fillna(VIC['Video graphics'].mode()[0], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2307195687.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   VIC['Display'].fillna('15.6', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2307195687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC['Display'].fillna('15.6', inplace=True)
# ...

# %% [markdown]
# #### 2. OR Mode as Value

# %%
VIC['Display'].fillna('15.6', inplace=True)
VIC['Display Resolution'].fillna('1920 x 1080', inplace=True)
VIC['Display Refresh Rate'].fillna('144 Hz', inplace=True)
VIC['Weight'].fillna('2.29 kg', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2454386910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC['Display'].fillna('15.6', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2454386910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC['Display Resolution'].fillna('1920 x 1080', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2454386910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
VIC.isnull().sum()
# Out:
# Processor               0
# RAM                     0
# Hard drive              0
# Display                 0
# Video graphics          0
# Display Resolution      0
# Display Refresh Rate    0
# Weight                  0
# Price                   0
# dtype: int64

# %%
VIC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Processor             1033 non-null   object
#  1   RAM                   1033 non-null   object
#  2   Hard drive            1033 non-null   object
#  3   Display               1033 non-null   object
#  4   Video graphics        1033 non-null   object
#  5   Display Resolution    1033 non-null   object
#  6   Display Refresh Rate  1033 non-null   object
#  7   Weight                1033 non-null   object
#  8   Price                 1033 non-null   int64
# dtypes: int64(1), object(8)
# memory usage: 72.8+ KB

# %%
VIC.duplicated().sum()
# Out:
# 22

# %%
VIC_df=VIC.drop_duplicates()

# %%
VIC_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Extracting numeric values from text columns
#
# Using regex to extract numbers from text columns and convert them to numeric types:
# - RAM: Extract first number (GB)
# - Weight: Extract first number (kg)
# - Screen size: Extract decimal number (inches)
# - Display Refresh Rate: Extract number (Hz)
# - GPU: Extract GPU model number
# - Storage: Extract storage capacity number
# - CPU: Extract processor generation number (4+ digits)

# %%
VIC_df['RAM'] = VIC_df['RAM'].str.extract(r'(\d+)').astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\4249234939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['RAM'] = VIC_df['RAM'].str.extract(r'(\d+)').astype(int)

# %%
VIC_df['Weight'] = VIC_df['Weight'].str.extract(r'(\d+(?:\.\d+)?)').astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\3108707212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['Weight'] = VIC_df['Weight'].str.extract(r'(\d+(?:\.\d+)?)').astype(float)

# %%
VIC_df['Screen size'] = VIC_df['Display'].str.extract(r'(\d+\.?\d+)').astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\2976875253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['Screen size'] = VIC_df['Display'].str.extract(r'(\d+\.?\d+)').astype(float)

# %%
VIC_df['Display Refresh Rate'] = VIC_df['Display Refresh Rate'].astype(str).str.extract(r'(\d+)').astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\3215348092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['Display Refresh Rate'] = VIC_df['Display Refresh Rate'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
VIC_df['GPU'] = VIC_df['Video graphics'].str.extract(r'(\d+)').astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\3023252799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['GPU'] = VIC_df['Video graphics'].str.extract(r'(\d+)').astype(float)

# %%
import re
VIC_df['Storage'] = VIC_df['Hard drive'].str.extract(r'(\d+)(?=\s*(?:GB|TB))', re.IGNORECASE).astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\374451437.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['Storage'] = VIC_df['Hard drive'].str.extract(r'(\d+)(?=\s*(?:GB|TB))', re.IGNORECASE).astype(float)

# %%
VIC_df['CPU'] = VIC_df['Processor'].str.extract(r'(\d{4,})').astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\4143400537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['CPU'] = VIC_df['Processor'].str.extract(r'(\d{4,})').astype(float)

# %% [markdown]
# #### Converting Storage values from TB to GB
#
# Converting storage capacity values: 1 TB = 1000 GB, 2 TB = 2000 GB

# %%
VIC_df['Storage'].loc[VIC_df['Storage'] == 1] =  1000
VIC_df['Storage'].loc[VIC_df['Storage'] == 2] =  2000
VIC_df['Storage'].loc[VIC_df['Storage'] == 4] =  4000
VIC_df['Storage'].loc[VIC_df['Storage'] == 6] =  6000
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\3812045882.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   VIC_df['Storage'].loc[VIC_df['Storage'] == 1] =  1000
# ...

# %% [markdown]
# #### Splitting Display Resolution into Width and Height + Setting it as float ( and price to float too)

# %%
VIC_df[['Screen Width', 'Screen Height']] = VIC_df['Display Resolution'].str.extract(r'(\d{3,4})\D+(\d{3,4})')
VIC_df['Screen Width'] = VIC_df['Screen Width'].astype(float)
VIC_df['Screen Height'] = VIC_df['Screen Height'].astype(float)
VIC_df['Price'] = VIC_df['Price'].astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\1958149971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df[['Screen Width', 'Screen Height']] = VIC_df['Display Resolution'].str.extract(r'(\d{3,4})\D+(\d{3,4})')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\1958149971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df[['Screen Width', 'Screen Height']] = VIC_df['Display Resolution'].str.extract(r'(\d{3,4})\D+(\d{3,4})')
# ...

# %%
VIC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1011 entries, 0 to 1032
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Processor             1011 non-null   object
#  1   RAM                   1011 non-null   int32
#  2   Hard drive            1011 non-null   object
#  3   Display               1011 non-null   object
#  4   Video graphics        1011 non-null   object
#  5   Display Resolution    1011 non-null   object
#  6   Display Refresh Rate  1011 non-null   int32
#  7   Weight                1011 non-null   float64
#  8   Price                 1011 non-null   float64
#  9   Screen size           1011 non-null   float64
#  10  GPU                   678 non-null    float64
#  11  Storage               1009 non-null   float64
#  12  CPU                   880 non-null    float64
#  13  Screen Width          1011 non-null   float64
#  14  Screen Height         1011 non-null   float64
# ...

# %% [markdown]
# #### Filling missing values with median

# %%
VIC_df['GPU'].fillna(VIC_df['GPU'].median(), inplace=True)
VIC_df['CPU'].fillna(VIC_df['CPU'].median(), inplace=True)
VIC_df['Storage'].fillna(VIC_df['Storage'].median(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\166717399.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   VIC_df['GPU'].fillna(VIC_df['GPU'].median(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\166717399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
VIC_df.shape
# Out:
# (1011, 15)

# %%
VIC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1011 entries, 0 to 1032
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Processor             1011 non-null   object
#  1   RAM                   1011 non-null   int32
#  2   Hard drive            1011 non-null   object
#  3   Display               1011 non-null   object
#  4   Video graphics        1011 non-null   object
#  5   Display Resolution    1011 non-null   object
#  6   Display Refresh Rate  1011 non-null   int32
#  7   Weight                1011 non-null   float64
#  8   Price                 1011 non-null   float64
#  9   Screen size           1011 non-null   float64
#  10  GPU                   1011 non-null   float64
#  11  Storage               1011 non-null   float64
#  12  CPU                   1011 non-null   float64
#  13  Screen Width          1011 non-null   float64
#  14  Screen Height         1011 non-null   float64
# ...

# %%
VIC_df.isnull().sum()
# Out:
# Processor               0
# RAM                     0
# Hard drive              0
# Display                 0
# Video graphics          0
# Display Resolution      0
# Display Refresh Rate    0
# Weight                  0
# Price                   0
# Screen size             0
# GPU                     0
# Storage                 0
# CPU                     0
# Screen Width            0
# Screen Height           0
# dtype: int64

# %%
VIC_df.tail(2)
# Out:
#                 Processor  RAM                    Hard drive  \
# 1031   AMD Ryzen™ 7-5800H   16  1TB SSD, M.2 NVMe™ PCIe® 3.0
# 1032  AMD Ryzen™ 9-5900HS   16   1TB M.2 NVMe™ PCIe® 3.0 SSD
#
#                                                 Display  \
# 1031  16" Inch OLED 4K, 16:10 aspect ratio, 0.2ms re...
# 1032  14''Inch WQHD (2560 x 1440) 16:9 anti-glare di...
#
#                   Video graphics Display Resolution  Display Refresh Rate  \
# 1031  NVIDIA® GeForce® RTX™ 3050        3840 x 2400                   144
# 1032   NVIDIA® GeForce RTX™ 3060   WQHD 2560 x 1440                   120
#
#       Weight    Price  Screen size     GPU  Storage     CPU  Screen Width  \
# 1031    1.95  34888.0         16.0  3050.0   1000.0  5800.0        3840.0
# 1032    1.60  45100.0         14.0  3060.0   1000.0  5900.0        2560.0
#
#       Screen Height
# 1031         2400.0
# 1032         1440.0

# %%
VIC_df['GPU'] = VIC_df['GPU'].astype(int)
VIC_df['CPU'] = VIC_df['CPU'].astype(int)
VIC_df['Storage'] = VIC_df['Storage'].astype(int)
VIC_df['Screen Width'] = VIC_df['Screen Width'].astype(int)
VIC_df['Screen Height'] = VIC_df['Screen Height'].astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\925598462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['GPU'] = VIC_df['GPU'].astype(int)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\925598462.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_df['CPU'] = VIC_df['CPU'].astype(int)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11808\925598462.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
VIC_df.head(1)
# Out:
#                   Processor  RAM  \
# 0  Intel Core Ultra 9 285HX   96
#
#                                           Hard drive  \
# 0  6TB, 2TB NVMe PCIe Gen5x4 SSD w/o DRAM + 2TB N...
#
#                                              Display  \
# 0  18" 16:10 UHD+ (3840x2400), MiniLED, 120Hz, 10...
#
#                  Video graphics Display Resolution  Display Refresh Rate  \
# 0  Nvidia GeForce RTX 5090 24GB          3840x2400                   120
#
#    Weight     Price  Screen size   GPU  Storage   CPU  Screen Width  \
# 0     3.6  320000.0         18.0  5090     6000  8290          3840
#
#    Screen Height
# 0           2400

# %%
VIC_Cleaned=VIC_df[['Processor','Display','Video graphics','Hard drive','Storage','RAM','Display Resolution','Screen size','Screen Height','Screen Width','Display Refresh Rate','CPU','GPU','Weight','Price']]

# %%
VIC_Cleaned.head(2)
# Out:
#                   Processor  \
# 0  Intel Core Ultra 9 285HX
# 1     Intel Core i9-14900HX
#
#                                              Display  \
# 0  18" 16:10 UHD+ (3840x2400), MiniLED, 120Hz, 10...
# 1   15.6" QHD (2560*1440), 165Hz DCI-P3 100% typical
#
#                  Video graphics  \
# 0  Nvidia GeForce RTX 5090 24GB
# 1   Nvidia GeForce RTX 5070 8GB
#
#                                           Hard drive  Storage  RAM  \
# 0  6TB, 2TB NVMe PCIe Gen5x4 SSD w/o DRAM + 2TB N...     6000   96
# 1                           1TB NVMe PCIe SSD Gen4x4     1000   16
#
#   Display Resolution  Screen size  Screen Height  Screen Width  \
# 0          3840x2400         18.0           2400          3840
# 1          2560*1440         15.6           1440          2560
#
#    Display Refresh Rate    CPU   GPU  Weight     Price
# 0                   120   8290  5090     3.6  320000.0
# 1                   165  14900  5070     2.4   79999.0

# %%
VIC_Cleaned[VIC_Cleaned['RAM']<4]
# Out:
#                       Processor  \
# 10      Intel® Core™ i5-12450HX
# 17       Intel® Core i9-14900HX
# 19    Intel® Core Ultra 9 275HX
# 36           AMD Ryzen 7 7435HS
# 38        Intel Core i7-14650HX
# ...                         ...
# 989      Intel® Core™ i5-1135G7
# 991        Intel Core I7-1165G7
# 1005       Intel Core i5-1135G7
# 1013       Intel Core I5-1135G7
# 1015       Intel Core i5-1135G7
#
#                                                 Display  \
# 10    15.6" FHD (1920x1080) IPS 300nits Anti-glare, ...
# 17    15.1" WQXGA OLED 1000nits (peak) / 500nits (ty...
# 19    16" WQXGA OLED 500nits (Typical) / 1100nits (P...
# 36    15.6" FHD IPS 300nits Anti-glare, 100% sRGB, 1...
# 38    16" WQXGA IPS 500nits Anti-glare, 100% DCI-P3,...
# ...                                                 ...
# 989   15.6" FHD (1920x1080) IPS 250nits Anti-glare, ...
# 991          15.6" FHD IPS 250nits Anti-glare, 45% NTSC
# 1005                     14" FHD IPS 250nits Anti-glare
# ...

# %%
VIC_Cleaned['RAM'].mode()
# Out:
# 0    16
# Name: RAM, dtype: int32

# %%
VIC_Cleaned.loc[(VIC_Cleaned['RAM'] < 4) & (VIC_Cleaned['Price'] >= 20000), 'RAM'] = 16
VIC_Cleaned.loc[(VIC_Cleaned['RAM'] < 4)& (VIC_Cleaned['Price'] <= 19999), 'RAM'] = 8

# %%
VIC_Cleaned[VIC_Cleaned['RAM']<4]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned[VIC_Cleaned['Storage']<128]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned[VIC_Cleaned['Storage']>6000]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned[VIC_Cleaned['Weight']<1]
# Out:
#                         Processor  \
# 616       Intel Core Ultra 7 155H
# 640        Snapdragon X X1 26 100
# 957  Snapdragon® X Plus (10 Core)
#
#                                                Display         Video graphics  \
# 616  13.3" 16:10, 2.8K (2880 x 1800) OLED panel, 10...     Intel Arc Graphics
# 640  14.0-inch, WUXGA (1920 x 1200) OLED 16:10 aspe...    Qualcomm Adreno GPU
# 957  Touchscreen: 13 inch PixelSense™ Flow display1...  Qualcomm® Adreno™ GPU
#
#                       Hard drive  Storage  RAM Display Resolution  \
# 616          512GB NVMe PCIe SSD      512   16        2880 x 1800
# 640  1TB M.2 NVMe™ PCIe® 4.0 SSD     1000   16        1920 x 1200
# 957                    512GB SSD      512   16        2880 x 1920
#
#      Screen size  Screen Height  Screen Width  Display Refresh Rate   CPU  \
# 616         13.3           1800          2880                   144  8290
# 640         14.0           1200          1920                    60  8290
# ...

# %%
VIC_Cleaned['Weight'].median()
# Out:
# 2.0

# %%
VIC_Cleaned.loc[VIC_Cleaned['Weight'] < 1, 'Weight']=2.0

# %%
VIC_Cleaned[VIC_Cleaned['Weight']<1]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned[VIC_Cleaned['Price']<6000]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned[VIC_Cleaned['Display Refresh Rate']<60]
# Out:
# Empty DataFrame
# Columns: [Processor, Display, Video graphics, Hard drive, Storage, RAM, Display Resolution, Screen size, Screen Height, Screen Width, Display Refresh Rate, CPU, GPU, Weight, Price]
# Index: []

# %%
VIC_Cleaned.to_csv("Cleaned_data.csv", index=False, encoding="utf-8-sig")

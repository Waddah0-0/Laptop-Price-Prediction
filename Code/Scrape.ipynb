# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %% [markdown]
# ## Scrapping laptops info from different categories :
# ######  gamming laptops from (1 - 24) pages (Maximum Pages)
# ######  personal laptops from (1 - 13) pages (Maximum Pages)
# ######  business laptops from (1 - 6) pages (Maximum Pages)
# ######  graphics and design laptops from (1) only one page

# %%
# https://egyptlaptop.com/laptops-category
laptops_categories = ["gaming-laptops-catlog", "personal-laptops" ,  "business-laptops-catlog" ,"graphics-and-design-laptops"]

# %% [markdown]
# #### count the number of fetched laptops:

# %%
counter=0
laptops_url_list=[]

# %% [markdown]
# #### Get all laptops titles from all pages in Gamming Laptops Category: (1 - 24) pages

# %%
for i in range(24):
    url =f"https://egyptlaptop.com/laptops-category/{laptops_categories[0]}/page-{i+1}/?items_per_page=32"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "lxml")
    all_titles = soup.find_all("a", {"class":"product-title"})
    counter += len(all_titles)
  
    for title in all_titles:
        link = title.attrs['href']
        laptops_url_list.append(link)

print(f"Total laptops: {counter}")
# Out:
# Total laptops: 576

# %% [markdown]
# #### Get all laptops titles from all pages in Personal Laptops Category: (1 - 13) pages

# %%
for i in range(13):
    url =f"https://egyptlaptop.com/laptops-category/{laptops_categories[1]}/page-{i+1}/?items_per_page=32"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "lxml")
    all_titles = soup.find_all("a", {"class":"product-title"})
    counter += len(all_titles)
   
    for title in all_titles:
        link = title.attrs['href']
        laptops_url_list.append(link)

print(f"Total laptops: {counter}")
# Out:
# Total laptops: 880

# %% [markdown]
# #### Get all laptops titles from all pages in Business Laptops Category: (1 - 6) pages

# %%
for i in range(6):
    url =f"https://egyptlaptop.com/laptops-category/{laptops_categories[2]}/page-{i+1}/?items_per_page=32"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "lxml")
    all_titles = soup.find_all("a", {"class":"product-title"})
    counter += len(all_titles)
    
    for title in all_titles:
        link = title.attrs['href']
        laptops_url_list.append(link)

print(f"Total laptops: {counter}")
# Out:
# Total laptops: 1018

# %% [markdown]
# #### Getting all laptops titles from the Design & Graphics Laptops Category: only one page

# %%
for i in range(1):
    url =f"https://egyptlaptop.com/laptops-category/{laptops_categories[3]}/page-{i+1}/?items_per_page=32"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "lxml")
    all_titles = soup.find_all("a", {"class":"product-title"})
    counter += len(all_titles)
   
    for title in all_titles:
        link = title.attrs['href']
        laptops_url_list.append(link)

print(f"Total laptops: {counter}")
# Out:
# Total laptops: 1033

# %% [markdown]
# ##### Print the total number of products

# %%
print(f"Total laptops: {counter}")
# Out:
# Total laptops: 1033

# %% [markdown]
# ##### Display the first 10 laptop URLs from the collected list

# %%
for i in range(10):
    print(laptops_url_list[i])
# Out:
# https://egyptlaptop.com/laptops/msi-titan-18-hx-dragon-edition-norse-myth-a2xwjg-gaming-laptop-intel-core-ultra-9-285hx-6tb-ssd-96gb-ram-nvidia-geforce-rtx-5090-24gb-18-inch-uhd-win-11-core-black
# https://egyptlaptop.com/laptops/msi-katana-15-hx-14xwgk-gaming-laptop-intel-core-i9-14900hx-1tb-ssd-16gb-ram-nvidia-geforce-rtx-5070-8gb-15-6-inch-qhdwin-11-black
# https://egyptlaptop.com/laptops/acer-nitro-v15-anv15-51-51h9-gaming-laptop-intel-core-i5-13420h-512gb-ssd-8gb-ram-nvidia-geforce-rtx-4050-6gb-15-6-inch-fhd-win-11-black
# https://egyptlaptop.com/laptops/dell-alienware-16-aurora-ac16250-gaming-laptop-intel-core-7-240h-512gb-ssd-16gb-ram-nvidia-geforce-rtx-5050-8gb-16-inch-wqxga
# https://egyptlaptop.com/laptops/dell-alienware-16-aurora-ac16250-gaming-laptop-intel-core-9-270h-1tb-ssd-16gb-ram-nvidia-geforce-rtx-5060-8gb-16-inch-wqxga
# https://egyptlaptop.com/laptops/dell-alienware-16-aurora-ac16250-gaming-laptop-intel-core-7-240h-1tb-ssd-32gb-ram-nvidia-geforce-rtx-5060-8gb16inchwqxga
# https://egyptlaptop.com/laptops/dell-alienware-16-aurora-ac16250-gaming-laptop-intel-core-ultra-7-240h-1tb-ssd-16gb-ram-nvidia-geforce-rtx-5050-8gb-16-inch-wqxga
# https://egyptlaptop.com/laptops/hp-victus-15-fa2318tx-gaming-laptop-intel-core-i7-13620h-512gb-ssd-16gb-ram-nvidia-geforce-rtx-3050-6gb-15-6-inch-fhd-mica-silver
# https://egyptlaptop.com/laptops/hp-victus-16-r1042ne-gaming-laptop-intel-core-i7-14700hx-512gb-ssd-16gb-ram-nvidia-geforce-rtx-4050-6gb-16-1inch-fhd-mica-silver
# https://egyptlaptop.com/laptops/hp-victus-15-fa2317tx-gaming-laptop-intel-core-i7-13620h-512gb-ssd-16gb-ram-nvidia-geforce-rtx-4050-6gb-15-6-inch-fhd-mica-silver

# %% [markdown]
# ##### Define a list that takes all laptop info as dictionary

# %%
all_laptops_data=[]

# %% [markdown]
# ##### Get all the laptop info from the laptop page details ( labels, values)

# %%
for i in range(len(laptops_url_list)):
    laptop_page_url =f"{laptops_url_list[i]}"
    laptop_page = requests.get(laptop_page_url)
    soup = BeautifulSoup(laptop_page.content, "lxml")
    
    price = soup.find("span", {"class":"ty-price-num"})
    features_list = soup.find_all("div" ,{"class":"ty-product-feature"})
    
    # laptop information dictionary
    laptop_info={}
    
    for feature in features_list: 
        # list of features labels
        labels = feature.contents[1].text.strip()
        # list of features values
        values = feature.contents[3].text.strip()
        laptop_info[labels]= values
       

    laptop_info["Price"] = int(price.text.strip().replace(",", ""))
    all_laptops_data.append(laptop_info)

# %% [markdown]
# ##### Get all dictionaries lables(keys) as a list to write header row in csv file:

# %%
all_keys = set()
for laptop in all_laptops_data:
    all_keys.update(laptop.keys())

fieldnames = sorted(all_keys)

print(fieldnames)
# Out:
# ['Battery', 'Brand:', 'Colors', 'Connections', 'Dimensions', 'Display', 'Display Refresh Rate', 'Display Resolution', 'Finger Print', 'Hard drive', 'Keyboard', 'Laptop Color', 'Operating System', 'Optical drive', 'Pointing device', 'Power supply type', 'Price', 'Processor', 'Processor Details', 'Processor Generation', 'Product name', 'Product number', 'RAM', 'SUPPORT SSD M2', 'Series :', 'Video graphics', 'Video graphics Memorey', 'Warranty', 'Webcam', 'Weight']

# %% [markdown]
# ##### Write all laptops data in csv file

# %%
with open("laptops_dataset.csv", "w", newline="", encoding="utf-8-sig") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(all_laptops_data)

# %%
df= pd.DataFrame(all_laptops_data)
df.to_csv(r"E:\Waddah\Alex\VS\Metho\DS Methodology Final Project\laptops_Dataset.csv", index=False, encoding="utf-8-sig")

# %%
df = pd.read_csv("laptops_dataset.csv")
df.head(2)
# Out:
#   Brand:                                  Product name  \
# 0    MSI  Titan 18 HX Dragon Edition Norse Myth A2XWJG
# 1    MSI                           Katana 15 HX 14XWGK
#
#                   Processor                Video graphics  \
# 0  Intel Core Ultra 9 285HX  Nvidia GeForce RTX 5090 24GB
# 1     Intel Core i9-14900HX   Nvidia GeForce RTX 5070 8GB
#
#   Video graphics Memorey                       RAM  \
# 0             24GB GDDR7  96GB DDR5 6400MHz 48GB*2
# 1              8GB GDDR7           16GB DDR5 8GB*2
#
#                                           Hard drive  \
# 0  6TB, 2TB NVMe PCIe Gen5x4 SSD w/o DRAM + 2TB N...
# 1                           1TB NVMe PCIe SSD Gen4x4
#
#                                              Display Display Resolution  \
# 0  18" 16:10 UHD+ (3840x2400), MiniLED, 120Hz, 10...          3840x2400
# 1   15.6" QHD (2560*1440), 165Hz DCI-P3 100% typical          2560*1440
#
#   Display Refresh Rate  ... Processor Generation Processor Details  \
# 0               120 Hz  ...                  NaN               NaN
# 1               165 HZ  ...      14th generation               NaN
#
#   Product number Power supply type Laptop Color Finger Print SUPPORT SSD M2  \
# 0            NaN               NaN          NaN          NaN            NaN
# 1            NaN               NaN          NaN          NaN            NaN
#
#   Pointing device Optical drive  Series :
# 0             NaN           NaN       NaN
# 1             NaN           NaN       NaN
#
# [2 rows x 30 columns]
